# %% [markdown]
# <a href="https://colab.research.google.com/github/Dalvisneha12/IBM_AIMI_Cloud_python/blob/main/Numpy%26pandas_Basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

array2 =np.array([12,34,56,82])

# %%
array2
# Out:
# array([12, 34, 56, 82])

# %%
array2[2]
# Out:
# 56

# %%
array2[1:3]
# Out:
# array([34, 56])

# %%
array2[1]='hari'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-1ad331f8e51a> in <cell line: 1>()
# ----> 1 array2[1]='hari'
#
# ValueError: invalid literal for int() with base 10: 'hari'

# %%
array2[1]=13
array2
# Out:
# array([12, 13, 56, 82])

# %%
array2.ndim
# type of dimension
# Out:
# 1

# %%
type(array2)
# Out:
# numpy.ndarray

# %%
array1=np.array([[12,23,54],[32,45,46]])
array1
# Out:
# array([[12, 23, 54],
#        [32, 45, 46]])

# %%
array1.ndim
# Out:
# 2

# %%
array1[1][0:2] # slicing and indexing
# Out:
# array([32, 45])

# %%
# functions and Methods
array1.dtype
# Out:
# dtype('int64')

# %%
type(array2)
# Out:
# numpy.ndarray

# %%
np.linspace(12,34,16) # methods in numpy
# Out:
# array([12.        , 13.46666667, 14.93333333, 16.4       , 17.86666667,
#        19.33333333, 20.8       , 22.26666667, 23.73333333, 25.2       ,
#        26.66666667, 28.13333333, 29.6       , 31.06666667, 32.53333333,
#        34.        ])

# %%
#pandas---> (Series, DataFrame)
demo1 = pd.Series(np.arange(3,6))
demo1
# Out:
# 0    3
# 1    4
# 2    5
# dtype: int64

# %%
demo2 = pd.Series(np.arange(13,16))
demo2
# Out:
# 0    13
# 1    14
# 2    15
# dtype: int64

# %%
demo3=pd.DataFrame(demo1,demo2)
demo3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-366f571d97c7> in <cell line: 1>()
# ----> 1 demo3=pd.DataFrame(demo1,demo2)
#       2 demo3
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     720                 )
#     721             else:
# --> 722                 mgr = ndarray_to_mgr(
#     723                     data,
#     724                     index,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     283             index = values.index
#     284         else:
# --> 285             values = values.reindex(index)
#     286
#     287         # zero len case (GH #2234)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in reindex(self, *args, **kwargs)
# ...

# %%
dummy = {'Name':['hari','samya','srikant','shivam',np.nan],
         'Age': [27,36,np.nan,29,25],
         'Track': ('AI','ML','CAD',np.nan,np.nan)}
dummy
# Out:
# {'Name': ['hari', 'samya', 'srikant', 'shivam', nan],
#  'Age': [27, 36, nan, 29, 25],
#  'Track': ('AI', 'ML', 'CAD', nan, nan)}

# %%
df = pd.DataFrame(dummy)
df
# Out:
#       Name   Age Track
# 0     hari  27.0    AI
# 1    samya  36.0    ML
# 2  srikant   NaN   CAD
# 3   shivam  29.0   NaN
# 4      NaN  25.0   NaN
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# df.groupby('Name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# df.groupby('Track').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# ...

# %%
df = pd.DataFrame(dummy)
df
# Out:
#       Name   Age Track
# 0     hari  27.0    AI
# 1    samya  36.0    ML
# 2  srikant   NaN   CAD
# 3   shivam  29.0   NaN
# 4      NaN  25.0   NaN

# %%
# to call only single columns, how to chech null values, how to replace null value, find the Data type
df
# Out:
#       Name   Age Track
# 0     hari  27.0    AI
# 1    samya  36.0    ML
# 2  srikant   NaN   CAD
# 3   shivam  29.0   NaN
# 4      NaN  25.0   NaN

# %%
df.Name
# Out:
# 0       hari
# 1      samya
# 2    srikant
# 3     shivam
# 4        NaN
# Name: Name, dtype: object

# %%
df['Name']# prefered method
# Out:
# 0       hari
# 1      samya
# 2    srikant
# 3     shivam
# 4        NaN
# Name: Name, dtype: object

# %%
# column as features
# row as observation

# %%
# how to find DB
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()  # info is the method name we get in details
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      float64
#  2   Track   3 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 248.0+ bytes

# %%
# always covnvert object into Interger
df.isnull()  # output in boolean
# Out:
#     Name    Age  Track
# 0  False  False  False
# 1  False  False  False
# 2  False   True  False
# 3  False  False   True
# 4   True  False   True

# %%
df.isnull().sum()
# we will be gettibg column name and total null values
# Out:
# Name     1
# Age      1
# Track    2
# dtype: int64

# %%
# loc & iloc
df.loc[: , :]  # repsersent column and rows
# Out:
#       Name   Age Track
# 0     hari  27.0    AI
# 1    samya  36.0    ML
# 2  srikant   NaN   CAD
# 3   shivam  29.0   NaN
# 4      NaN  25.0   NaN

# %%
df.loc[0:2,'Name':'Age']
# Out:
#       Name   Age
# 0     hari  27.0
# 1    samya  36.0
# 2  srikant   NaN

# %%
df.iloc[0:3,0:2] # prefered
# Out:
#       Name   Age
# 0     hari  27.0
# 1    samya  36.0
# 2  srikant   NaN

# %%
# !unzip '/content/archive (30).zip
# Out:
# /bin/bash: -c: line 1: unexpected EOF while looking for matching `''
# /bin/bash: -c: line 2: syntax error: unexpected end of file

# %% [markdown]
# # **Basic** **Preprocessing**

# %%
# !unzip '/content/ObesityDataSet.csv.zip'
# Out:
# unzip:  cannot find or open /content/ObesityDataSet.csv.zip, /content/ObesityDataSet.csv.zip.zip or /content/ObesityDataSet.csv.zip.ZIP.

# %%
df = pd.read_csv('/content/ObesityDataSet.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c94c75876c2a> in <cell line: 1>()
# ----> 1 df = pd.read_csv('/content/ObesityDataSet.csv')
#       2 df.head()
#
# NameError: name 'pd' is not defined

# %%
df = pd .read_csv('/content/ObesityDataSet.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-9df40372182f> in <cell line: 1>()
# ----> 1 df = pd .read_csv('/content/ObesityDataSet.csv')
#       2 df.head()
#
# NameError: name 'pd' is not defined

# %%
# !unzip'/content/archive (30).zip'
# Out:
# /bin/bash: line 1: unzip/content/archive (30).zip: No such file or directory

# %%
import pandas as pd
import numpy as np

# %%
df = pd .read_csv('/content/ObesityDataSet.csv')
df.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# ...

# %%
df['Gender'].value_counts()
# Out:
# 0    1068
# 1    1043
# Name: Gender, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
# ...

# %%
# Encoding the data  ( why to convery object in to numerial values) becaause AIML is in numericalvalues so we convert object into numerial value to work on datasets.

# %%
# 1) label encoding 2) one hot encoding 3) manual encoding

# %%
df['Gender'].value_counts()
# Out:
# Male      1068
# Female    1043
# Name: Gender, dtype: int64

# %%
df.head(3)
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0       1  21.0    1.62    64.0                            yes   no   2.0
# 1       1  21.0    1.52    56.0                            yes   no   3.0
# 2       0  23.0    1.80    77.0                            yes   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
#
#                   MTRANS     NObeyesdad
# 0  Public_Transportation  Normal_Weight
# 1  Public_Transportation  Normal_Weight
# 2  Public_Transportation  Normal_Weight

# %%
#Manual Encoding
df['Gender'] =df['Gender'].replace({'Male':0,'Female':1})

# %%
df.head(3)
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0       1  21.0    1.62    64.0                            yes   no   2.0
# 1       1  21.0    1.52    56.0                            yes   no   3.0
# 2       0  23.0    1.80    77.0                            yes   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
#
#                   MTRANS     NObeyesdad
# 0  Public_Transportation  Normal_Weight
# 1  Public_Transportation  Normal_Weight
# 2  Public_Transportation  Normal_Weight

# %%
df['FAVC'].value_counts()
# Out:
# yes    1866
# no      245
# Name: FAVC, dtype: int64

# %%
df['FAVC'] = df['FAVC'].replace({'yes':1,'no':0})

# %%
df.head(2)
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight  FAVC  FCVC  \
# 0       1  21.0    1.62    64.0                            yes     0   2.0
# 1       1  21.0    1.52    56.0                            yes     0   3.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE       CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0         no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0  Sometimes
#
#                   MTRANS     NObeyesdad
# 0  Public_Transportation  Normal_Weight
# 1  Public_Transportation  Normal_Weight

# %%
df['family_history_with_overweight'].value_counts()
# Out:
# yes    1726
# no      385
# Name: family_history_with_overweight, dtype: int64

# %%
df['family_history_with_overweight'] = df['family_history_with_overweight'].replace({'yes':1,'no':0})

# %%
df.head(2)
# Out:
#    Gender   Age  Height  Weight  family_history_with_overweight  FAVC  FCVC  \
# 0       1  21.0    1.62    64.0                               1     0   2.0
# 1       1  21.0    1.52    56.0                               1     0   3.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE       CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0         no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0  Sometimes
#
#                   MTRANS     NObeyesdad
# 0  Public_Transportation  Normal_Weight
# 1  Public_Transportation  Normal_Weight

# %%
# one hot Encoding only convert it to 0 either 1

# %%
pd.get_dummies(df['CAEC'])
# Out:
#       Always  Frequently  Sometimes  no
# 0          0           0          1   0
# 1          0           0          1   0
# 2          0           0          1   0
# 3          0           0          1   0
# 4          0           0          1   0
# ...      ...         ...        ...  ..
# 2106       0           0          1   0
# 2107       0           0          1   0
# 2108       0           0          1   0
# 2109       0           0          1   0
# 2110       0           0          1   0
#
# [2111 rows x 4 columns]

# %%
df['CAEC'].value_counts()  # convert caterory into columns # one hot encoding
# Out:
# Sometimes     1765
# Frequently     242
# Always          53
# no              51
# Name: CAEC, dtype: int64

# %%
Which one is better from  above three
lable : automatically the value will be assigned
# LABLE ENCODING SKLEARN LIBARY is been used (label encoder comes under sklearn package)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder() # initialization of module # assignment value Alphabetical oredr

# %%
df['CAEC'] =le.fit_transform(df['CAEC'])

# %%
df.head(3)
# Out:
#    Gender   Age  Height  Weight  family_history_with_overweight  FAVC  FCVC  \
# 0       1  21.0    1.62    64.0                               1     0   2.0
# 1       1  21.0    1.52    56.0                               1     0   3.0
# 2       0  23.0    1.80    77.0                               1     0   2.0
#
#    NCP  CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0  3.0     2    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1  3.0     2   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  3.0     2    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
#
#       NObeyesdad
# 0  Normal_Weight
# 1  Normal_Weight
# 2  Normal_Weight

# %%
# Hari # Srikanth # Saumya ( follow alphabetical order )
#  0 #    2    # 1   # this  is how label encoder work

# %%
df['CALC']. value_counts()
# Out:
# Sometimes     1401
# no             639
# Frequently      70
# Always           1
# Name: CALC, dtype: int64

# %%
df['CALC'] =le.fit_transform(df['CALC'])

# %%
df.head(3)
# Out:
#    Gender   Age  Height  Weight  family_history_with_overweight  FAVC  FCVC  \
# 0       1  21.0    1.62    64.0                               1     0   2.0
# 1       1  21.0    1.52    56.0                               1     0   3.0
# 2       0  23.0    1.80    77.0                               1     0   2.0
#
#    NCP  CAEC SMOKE  CH2O  SCC  FAF  TUE  CALC                 MTRANS  \
# 0  3.0     2    no   2.0   no  0.0  1.0     3  Public_Transportation
# 1  3.0     2   yes   3.0  yes  3.0  0.0     2  Public_Transportation
# 2  3.0     2    no   2.0   no  2.0  1.0     1  Public_Transportation
#
#       NObeyesdad
# 0  Normal_Weight
# 1  Normal_Weight
# 2  Normal_Weight

# %%
df['SMOKE']. value_counts()
# Out:
# no     2067
# yes      44
# Name: SMOKE, dtype: int64

# %%
df['SMOKE'] =le.fit_transform(df['SMOKE'])

# %%
df.head(3)
# Out:
#    Gender   Age  Height  Weight  family_history_with_overweight  FAVC  FCVC  \
# 0       1  21.0    1.62    64.0                               1     0   2.0
# 1       1  21.0    1.52    56.0                               1     0   3.0
# 2       0  23.0    1.80    77.0                               1     0   2.0
#
#    NCP  CAEC  SMOKE  CH2O  SCC  FAF  TUE  CALC                 MTRANS  \
# 0  3.0     2      0   2.0   no  0.0  1.0     3  Public_Transportation
# 1  3.0     2      1   3.0  yes  3.0  0.0     2  Public_Transportation
# 2  3.0     2      0   2.0   no  2.0  1.0     1  Public_Transportation
#
#       NObeyesdad
# 0  Normal_Weight
# 1  Normal_Weight
# 2  Normal_Weight

# %%
df['CH2O']. value_counts()
# Out:
# 2.000000    448
# 1.000000    211
# 3.000000    162
# 2.825629      3
# 1.636326      3
#            ...
# 1.622638      1
# 2.452986      1
# 2.035954      1
# 1.944095      1
# 2.863513      1
# Name: CH2O, Length: 1268, dtype: int64

# %%
df['CH2O'] =le.fit_transform(df['CH2O'])

# %%
df.head(3)
# Out:
#    Gender   Age  Height  Weight  family_history_with_overweight  FAVC  FCVC  \
# 0       1  21.0    1.62    64.0                               1     0   2.0
# 1       1  21.0    1.52    56.0                               1     0   3.0
# 2       0  23.0    1.80    77.0                               1     0   2.0
#
#    NCP  CAEC  SMOKE  CH2O  SCC  FAF  TUE  CALC                 MTRANS  \
# 0  3.0     2      0   549   no  0.0  1.0     3  Public_Transportation
# 1  3.0     2      1  1267  yes  3.0  0.0     2  Public_Transportation
# 2  3.0     2      0   549   no  2.0  1.0     1  Public_Transportation
#
#       NObeyesdad
# 0  Normal_Weight
# 1  Normal_Weight
# 2  Normal_Weight

# %%
df['SCC']. value_counts()
# Out:
# no     2015
# yes      96
# Name: SCC, dtype: int64

# %%
df['SCC'] =le.fit_transform(df['SCC'])

# %%
df.head(3)
# Out:
#    Gender   Age  Height  Weight  family_history_with_overweight  FAVC  FCVC  \
# 0       1  21.0    1.62    64.0                               1     0   2.0
# 1       1  21.0    1.52    56.0                               1     0   3.0
# 2       0  23.0    1.80    77.0                               1     0   2.0
#
#    NCP  CAEC  SMOKE  CH2O  SCC  FAF  TUE  CALC                 MTRANS  \
# 0  3.0     2      0   549    0  0.0  1.0     3  Public_Transportation
# 1  3.0     2      1  1267    1  3.0  0.0     2  Public_Transportation
# 2  3.0     2      0   549    0  2.0  1.0     1  Public_Transportation
#
#       NObeyesdad
# 0  Normal_Weight
# 1  Normal_Weight
# 2  Normal_Weight

# %%
df['MTRANS']. value_counts()
# Out:
# Public_Transportation    1580
# Automobile                457
# Walking                    56
# Motorbike                  11
# Bike                        7
# Name: MTRANS, dtype: int64

# %%
df['MTRANS'] =le.fit_transform(df['MTRANS'])

# %%
df.head(3)
# Out:
#    Gender   Age  Height  Weight  family_history_with_overweight  FAVC  FCVC  \
# 0       1  21.0    1.62    64.0                               1     0   2.0
# 1       1  21.0    1.52    56.0                               1     0   3.0
# 2       0  23.0    1.80    77.0                               1     0   2.0
#
#    NCP  CAEC  SMOKE  CH2O  SCC  FAF  TUE  CALC  MTRANS     NObeyesdad
# 0  3.0     2      0   549    0  0.0  1.0     3       3  Normal_Weight
# 1  3.0     2      1  1267    1  3.0  0.0     2       3  Normal_Weight
# 2  3.0     2      0   549    0  2.0  1.0     1       3  Normal_Weight

# %%
# retrive the original data

# %%
le.inverse_transform([3])
# Out:
# array(['Public_Transportation'], dtype=object)
